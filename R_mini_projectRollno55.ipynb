# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhivarande/RLAb/blob/main/R_mini_projectRollno55.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
info<-read.csv("https://raw.githubusercontent.com/Venkateshvk29/Rlab/main/healthcare-dataset-stroke-data.csv")
info
# Out:
#      id    gender age   hypertension heart_disease ever_married work_type
# 1     9046 Male   67    0            1             Yes          Private
# 2    51676 Female 61    0            0             Yes          Self-employed
# 3    31112 Male   80    0            1             Yes          Private
# 4    60182 Female 49    0            0             Yes          Private
# 5     1665 Female 79    1            0             Yes          Self-employed
# 6    56669 Male   81    0            0             Yes          Private
# 7    53882 Male   74    1            1             Yes          Private
# 8    10434 Female 69    0            0             No           Private
# 9    27419 Female 59    0            0             Yes          Private
# 10   60491 Female 78    0            0             Yes          Private
# 11   12109 Female 81    1            0             Yes          Private
# 12   12095 Female 61    0            1             Yes          Govt_job
# ...

# %%
summary(info)
# Out:
#        id           gender               age         hypertension
#  Min.   :   67   Length:5110        Min.   : 0.08   Min.   :0.00000
#  1st Qu.:17741   Class :character   1st Qu.:25.00   1st Qu.:0.00000
#  Median :36932   Mode  :character   Median :45.00   Median :0.00000
#  Mean   :36518                      Mean   :43.23   Mean   :0.09746
#  3rd Qu.:54682                      3rd Qu.:61.00   3rd Qu.:0.00000
#  Max.   :72940                      Max.   :82.00   Max.   :1.00000
#  heart_disease     ever_married        work_type         Residence_type
#  Min.   :0.00000   Length:5110        Length:5110        Length:5110
#  1st Qu.:0.00000   Class :character   Class :character   Class :character
#  Median :0.00000   Mode  :character   Mode  :character   Mode  :character
#  Mean   :0.05401
#  3rd Qu.:0.00000
#  Max.   :1.00000
#  avg_glucose_level     bmi            smoking_status         stroke
#  Min.   : 55.12    Length:5110        Length:5110        Min.   :0.00000
# ...

# %%
info[c("age")]
# Out:
#      age
# 1    67
# 2    61
# 3    80
# 4    49
# 5    79
# 6    81
# 7    74
# 8    69
# 9    59
# 10   78
# 11   81
# 12   61
# 13   54
# 14   78
# 15   79
# 16   50
# 17   64
# 18   75
# 19   60
# 20   57
# 21   71
# 22   52
# 23   79
# 24   82
# 25   71
# 26   80
# 27   65
# 28   58
# 29   69
# 30   59
# ⋮    ⋮
# 5081 29.00
# 5082 55.00
# 5083 44.00
# 5084 19.00
# 5085 67.00
# 5086 72.00
# 5087 51.00
# 5088 63.00
# 5089 64.00
# 5090  0.72
# 5091 26.00
# 5092 59.00
# 5093 76.00
# 5094 45.00
# 5095 13.00
# 5096  1.08
# 5097 57.00
# 5098 68.00
# 5099  9.00
# 5100 40.00
# 5101 82.00
# 5102 45.00
# 5103 57.00
# 5104 18.00
# 5105 13.00
# 5106 80.00
# 5107 81.00
# 5108 35.00
# 5109 51.00
# 5110 44.00

# %%
nameAge <-info[c("gender","age")]
nameAge
# Out:
#      gender age
# 1    Male   67
# 2    Female 61
# 3    Male   80
# 4    Female 49
# 5    Female 79
# 6    Male   81
# 7    Male   74
# 8    Female 69
# 9    Female 59
# 10   Female 78
# 11   Female 81
# 12   Female 61
# 13   Female 54
# 14   Male   78
# 15   Female 79
# 16   Female 50
# 17   Male   64
# 18   Male   75
# 19   Female 60
# 20   Male   57
# 21   Female 71
# 22   Female 52
# 23   Female 79
# 24   Male   82
# 25   Male   71
# 26   Male   80
# 27   Female 65
# 28   Male   58
# 29   Male   69
# 30   Male   59
# ⋮    ⋮      ⋮
# 5081 Female 29.00
# 5082 Male   55.00
# 5083 Female 44.00
# 5084 Female 19.00
# 5085 Male   67.00
# 5086 Female 72.00
# 5087 Female 51.00
# 5088 Female 63.00
# 5089 Female 64.00
# 5090 Female  0.72
# 5091 Male   26.00
# 5092 Male   59.00
# 5093 Male   76.00
# 5094 Female 45.00
# 5095 Male   13.00
# 5096 Male    1.08
# 5097 Male   57.00
# 5098 Male   68.00
# 5099 Male    9.00
# 5100 Male   40.00
# 5101 Male   82.00
# 5102 Female 45.00
# ...

# %%
Nseries = function(n,m){
  a=n+m
  info[n:a,]
}

# %%
Nseries(2,3)
# Out:
#   id    gender age hypertension heart_disease ever_married work_type
# 2 51676 Female 61  0            0             Yes          Self-employed
# 3 31112 Male   80  0            1             Yes          Private
# 4 60182 Female 49  0            0             Yes          Private
# 5  1665 Female 79  1            0             Yes          Self-employed
#   Residence_type avg_glucose_level bmi  smoking_status stroke
# 2 Rural          202.21            N/A  never smoked   1
# 3 Rural          105.92            32.5 never smoked   1
# 4 Urban          171.23            34.4 smokes         1
# 5 Rural          174.12            24   never smoked   1

# %%
colSums(is.na(info))
# Out:
#                id            gender               age      hypertension
#                 0                 0                 0                 0
#     heart_disease      ever_married         work_type    Residence_type
#                 0                 0                 0                 0
# avg_glucose_level               bmi    smoking_status            stroke
#                 0                 0                 0                 0

# %%
sample_info_1less <- subset(info,select = -c(bmi))
head(sample_info_1less)
# Out:
#   id    gender age hypertension heart_disease ever_married work_type
# 1  9046 Male   67  0            1             Yes          Private
# 2 51676 Female 61  0            0             Yes          Self-employed
# 3 31112 Male   80  0            1             Yes          Private
# 4 60182 Female 49  0            0             Yes          Private
# 5  1665 Female 79  1            0             Yes          Self-employed
# 6 56669 Male   81  0            0             Yes          Private
#   Residence_type avg_glucose_level smoking_status  stroke
# 1 Urban          228.69            formerly smoked 1
# 2 Rural          202.21            never smoked    1
# 3 Rural          105.92            never smoked    1
# 4 Urban          171.23            smokes          1
# 5 Rural          174.12            never smoked    1
# 6 Urban          186.21            formerly smoked 1

# %%
summary(sample_info_1less)
# Out:
#        id           gender               age         hypertension
#  Min.   :   67   Length:5110        Min.   : 0.08   Min.   :0.00000
#  1st Qu.:17741   Class :character   1st Qu.:25.00   1st Qu.:0.00000
#  Median :36932   Mode  :character   Median :45.00   Median :0.00000
#  Mean   :36518                      Mean   :43.23   Mean   :0.09746
#  3rd Qu.:54682                      3rd Qu.:61.00   3rd Qu.:0.00000
#  Max.   :72940                      Max.   :82.00   Max.   :1.00000
#  heart_disease     ever_married        work_type         Residence_type
#  Min.   :0.00000   Length:5110        Length:5110        Length:5110
#  1st Qu.:0.00000   Class :character   Class :character   Class :character
#  Median :0.00000   Mode  :character   Mode  :character   Mode  :character
#  Mean   :0.05401
#  3rd Qu.:0.00000
#  Max.   :1.00000
#  avg_glucose_level smoking_status         stroke
#  Min.   : 55.12    Length:5110        Min.   :0.00000
# ...

# %%
# d. For attribute having maximum spread delete all tuples that have value less than the mean of the
# attribute selected. Count the number of tuples reamining in the sampled dataset.
m <- mean(info$hypertension, na.rm = FALSE)
m

df2 <- subset(info, info$hypertension< m)
summary(df2$hypertension)
print('Rows before row deletion: ')
nrow(info)
print('Rows before row deletion: ')
nrow(df2)
# Out:
# [1] 0.09745597
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0       0       0       0       0       0
# [1] "Rows before row deletion: "
# [1] 5110
# [1] "Rows before row deletion: "
# [1] 4612

# %%
fivenum(info$age)
fivenum(info$heart_disease)
# Out:
# [1]  0.08 25.00 45.00 61.00 82.00
# [1] 0 0 0 0 1

# %%
# b. select 2 atributes have closest mean value and draw a scatter plot with proper x and labelsloi
# ntt and title (for plotting you must use R library functions or gnuplot and not matplotlib )
means<- colMeans(info[sapply(info, is.numeric)] )
means

library(ggplot2)

age<-info$age
avg_glucose_level<-info$avg_glucose_level
plot(info$age , info$avg_glucose_level , main = "Scatterplot" , xlab = "age" , ylab = "avg_glucose_level" , las = 1 , xlim = c(0,2) , col = 2 )
# Out:
#                id               age      hypertension     heart_disease
#      3.651783e+04      4.322661e+01      9.745597e-02      5.401174e-02
# avg_glucose_level            stroke
#      1.061477e+02      4.872798e-02
# Plot with title “Scatterplot”

# %%
# e. Write a R function to plot histogram of some specific input attribute for any data set provided
new.function <- function(age) {
   hist(age)
}

new.function(age)
# Out:
# Plot with title “Histogram of age”

# %%
# c. Find coefficient of correlation using some R library function between above 2 attributes
cor(age,avg_glucose_level, method = c("pearson", "kendall", "spearman"))
# Out:
# [1] 0.2381711

# %%
boxplot(age,avg_glucose_level)
title("age vs. avg_glucose_level")
# Out:
# Plot with title “age vs. avg_glucose_level”

# %%
boxplot(avg_glucose_level~age,info=info, main="Box Plot",
   xlab="avg_glucose_level", ylab="age")
# Out:
# Plot with title “Box Plot”
